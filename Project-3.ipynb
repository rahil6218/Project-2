# %% [markdown]
# PROJECT 1

# %%
import pandas as pd

# %%
d=pd.read_csv(r"Desktop/Book1 2.csv")

# %%
IMDB
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
## Q1  Display Top 10 Rows of The Dataset
IMDB.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
#Q2.bottom 10 rows of the dataset
IMDB.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
#Q3.Find Shape of Our Dataset (Number of Rows And Number of Columns)
IMDB.shape
# Out:
# (1000, 12)

# %%
#Q4.Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns,\
## Datatypes of Each Column And Memory Requirement
IMDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#Q5.Check Missing Values In The Dataset
IMDB.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
IMDB.notnull().sum()
# Out:
# Rank                  1000
# Title                 1000
# Genre                 1000
# Description           1000
# Director              1000
# Actors                1000
# Year                  1000
# Runtime (Minutes)     1000
# Rating                1000
# Votes                 1000
# Revenue (Millions)     872
# Metascore              936
# dtype: int64

# %%
IMDB
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#Q6.Finding the mean of the column
m=IMDB["Revenue (Millions)"].mean()

# %%
m
# Out:
# 82.95637614678898

# %%
#Filling the Mean into that column in place of null values
IMDB["Revenue (Millions)"]=IMDB[("Revenue (Millions)")].fillna(m)

# %%
IMDB.isna().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
#Q6. Drop the unwanted column which has null value and value of no use 
IMDB.dropna(axis=1,inplace=True) #it will delete the meta colummn

# %%
IMDB #there is no meta column remaining
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
IMDB.shape
# Out:
# (1000, 11)

# %%
#Q7.Check For Duplicate Data
IMDB.duplicated().sum()
# Out:
# 0

# %%
#Q8.Display Title of The Movie Having Runtime Greater Than or equal to 180 Minutes
IMDB[IMDB['Runtime (Minutes)']>=180][["Title","Runtime (Minutes)"]]
# Out:
#                        Title  Runtime (Minutes)
# 82   The Wolf of Wall Street                180
# 88         The Hateful Eight                187
# 311           La vie d'Adèle                180
# 828               Grindhouse                191
# 965            Inland Empire                180

# %%
#Q9. In Which Year There Was The Highest Average Voting?
IMDB["Year"].unique()
# Out:
# array([2014, 2012, 2016, 2015, 2007, 2011, 2008, 2006, 2009, 2010, 2013])

# %%
IMBD["Year"].nunique()
# Out:
# 11

# %%
IMDB.groupby('Year')['Votes'].mean().sort_values(ascending= False)e
# Out:
# Year
# 2012    285226.093750
# 2008    275505.384615
# 2006    269289.954545
# 2009    255780.647059
# 2010    252782.316667
# 2007    244331.037736
# 2011    240790.301587
# 2013    219049.648352
# 2014    203930.224490
# 2015    115726.220472
# 2016     48591.754209
# Name: Votes, dtype: float64

# %%
#Q10.Year wise no of movies.
IMDB['Year'].value_counts()
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %%
#Q11.In Which Year There Was The Highest Average Revenue?
IMDB.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    110.276186
# 2012    107.973281
# 2010    103.975319
# 2008     98.772623
# 2011     87.538355
# 2007     87.510481
# 2013     86.984496
# 2006     86.144835
# 2014     84.992097
# 2015     78.862278
# 2016     63.446588
# Name: Revenue (Millions), dtype: float64

# %%
IMDB.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)
# 0     8.1  757074              333.13
# 1     7.0  485820              126.46

# %%
#Q12.Find The Average Rating For Each Director
IMDB.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Nitesh Tiwari        8.80
# Christopher Nolan    8.68
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Aamir Khan           8.50
#                      ...
# Micheal Bafaro       3.50
# Jonathan Holbrook    3.20
# Shawn Burkett        2.70
# James Wong           2.70
# Jason Friedberg      1.90
# Name: Rating, Length: 644, dtype: float64

# %%
#Q13.Find the number of movies particular director did
IMDB['Director'].value_counts()
# Out:
# Director
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
#                      ..
# Lee Toland Krieger    1
# Gillies MacKinnon     1
# Peter Atencio         1
# James Mangold         1
# Scot Armstrong        1
# Name: count, Length: 644, dtype: int64

# %%
#Q14.Find the name of movie did by particular director
IMDB[IMDB['Director']=='James Mangold']
# Out:
#      Rank          Title                    Genre  \
# 388   389  The Wolverine  Action,Adventure,Sci-Fi
#
#                                            Description       Director  \
# 388  When Wolverine is summoned to Japan by an old ...  James Mangold
#
#                                                 Actors  Year  \
# 388  Hugh Jackman, Will Yun Lee, Tao Okamoto, Rila ...  2013
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)
# 388                126     6.7  355362              132.55

# %%
IMDB[IMDB['Director']=='David Yates']
# Out:
#      Rank                                         Title  \
# 10     11       Fantastic Beasts and Where to Find Them
# 107   108                          The Legend of Tarzan
# 114   115  Harry Potter and the Deathly Hallows: Part 2
# 314   315     Harry Potter and the Order of the Phoenix
# 418   419  Harry Potter and the Deathly Hallows: Part 1
# 473   474        Harry Potter and the Half-Blood Prince
#
#                         Genre  \
# 10   Adventure,Family,Fantasy
# 107    Action,Adventure,Drama
# 114   Adventure,Drama,Fantasy
# 314  Adventure,Family,Fantasy
# 418  Adventure,Family,Fantasy
# 473  Adventure,Family,Fantasy
#
#                                            Description     Director  \
# 10   The adventures of writer Newt Scamander in New...  David Yates
# 107  Tarzan, having acclimated to life in London, i...  David Yates
# 114  Harry, Ron and Hermione search for Voldemort's...  David Yates
# 314  With their warning about Lord Voldemort's retu...  David Yates
# ...

# %%
#Q15.Display Top 10 Lengthy Movies Title and Runtime
IMDB.nlargest(10,"Runtime (Minutes)")[["Title","Runtime (Minutes)"]]
# Out:
#                                         Title  Runtime (Minutes)
# 828                                Grindhouse                191
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 965                             Inland Empire                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 36                               Interstellar                169
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169

# %%
#Q16.Display Top 10 shortest Movies Title and Runtime
IMDB.nsmallest(10,"Runtime (Minutes)")[["Title","Runtime (Minutes)"]]
# Out:
#                                                  Title  Runtime (Minutes)
# 793                                Ma vie de Courgette                 66
# 42                             Don't Fuck in the Woods                 73
# 819                                 Wolves at the Door                 73
# 711                                    La tortue rouge                 80
# 949                                              Kicks                 80
# 258                                         Lights Out                 81
# 317                                    The Stakelander                 81
# 382                                               Hush                 81
# 444                                       The Thinning                 81
# 862  Alexander and the Terrible, Horrible, No Good,...                 81

# %%
IMDB.nsmallest(7,"Rating")[["Title","Rating"]]
# Out:
#                        Title  Rating
# 829           Disaster Movie     1.9
# 42   Don't Fuck in the Woods     2.7
# 871     Dragonball Evolution     2.7
# 647                 Tall Men     3.2
# 890               The Intent     3.5
# 968                  Wrecker     3.5
# 49             The Last Face     3.7

# %%
#Q17.Find Most Popular Movie Title (Highest Revenue)

# %%
IMDB.nlargest(1,'Rating')[["Title","Rating"]]
# Out:
#               Title  Rating
# 54  The Dark Knight     9.0

# %%
IMDB.nlargest(1,'Revenue (Millions)')[["Title","Revenue (Millions)"]]
# Out:
#                                          Title  Revenue (Millions)
# 50  Star Wars: Episode VII - The Force Awakens              936.63

# %%
#also there is one more way
IMDB["Revenue (Millions)"].max()
# Out:
# 936.63

# %%
IMDB[IMDB["Revenue (Millions)"]==936.63]
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)
# 50                136     8.1  661608              936.63

# %%
#Q18.Display Top 10 Highest Revenue Movie Titles
IMDB.nlargest(10,'Revenue (Millions)')[["Title","Revenue (Millions)"]]
# Out:
#                                           Title  Revenue (Millions)
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 87                                       Avatar              760.51
# 85                               Jurassic World              652.18
# 76                                 The Avengers              623.28
# 54                              The Dark Knight              533.32
# 12                                    Rogue One              532.17
# 119                                Finding Dory              486.29
# 94                      Avengers: Age of Ultron              458.99
# 124                       The Dark Knight Rises              448.13
# 578             The Hunger Games: Catching Fire              424.65

# %%
#Q19.Display Top 10 Highest Rated Movie Titles And its Directors
IMDB.nlargest(10,"Rating")[["Title","Director","Genre"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Q19.Display Top 10 Highest Rated Movie Titles And its Directors
# ----> 2 IMDB.nlargest(10,"Rating")[["Title","Director","Genre"]]
#
# NameError: name 'IMDB' is not defined

# %%
#Q20.Find Average Rating of Movies Year Wise
IMDB['Year'].value_counts()
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %%
IMDB.groupby('Year')["Rating"].mean()
# Out:
# Year
# 2006    7.125000
# 2007    7.133962
# 2008    6.784615
# 2009    6.960784
# 2010    6.826667
# 2011    6.838095
# 2012    6.925000
# 2013    6.812088
# 2014    6.837755
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %%
#Q21.Classify Movies Based on Ratings [Excellent, Good, and Average]
def classs(x):
    if x>=7.0:
        return "EXCELLENT"
    elif x>=5.0:
        return "GOOD"

    elif x<5.0:
        return "BAD"

# %%
IMDB["Review"]=IMDB["Rating"].apply(classs)

# %%
IMDB.head(30)
# Out:
#     Rank                                    Title                       Genre  \
# 0      1                  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 7      8                                 Mindhorn                      Comedy
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# ...

# %%
#Q22. Count Number of Action Movies
IMDB[IMDB["Genre"]=='Action']
# Out:
#      Rank                 Title   Genre  \
# 123   124  Boyka: Undisputed IV  Action
# 580   581  Kickboxer: Vengeance  Action
#
#                                            Description         Director  \
# 123  In the fourth installment of the fighting fran...  Todor Chapkanov
# 580         A kick boxer is out to avenge his brother.   John Stockwell
#
#                                                 Actors  Year  \
# 123  Scott Adkins, Teodora Duhovnikova, Alon Aboutb...  2016
# 580  Dave Bautista, Alain Moussi, Gina Carano, Jean...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)     Review
# 123                 86     7.4  10428           82.956376  EXCELLENT
# 580                 90     4.9   6809          131.560000        BAD

# %%
IMDB[IMDB["Genre"].str.contains('Action')]
# Out:
#      Rank                           Title                       Genre  \
# 0       1         Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 4       5                   Suicide Squad    Action,Adventure,Fantasy
# 5       6                  The Great Wall    Action,Adventure,Fantasy
# 8       9              The Lost City of Z  Action,Adventure,Biography
# 12     13                       Rogue One     Action,Adventure,Sci-Fi
# ..    ...                             ...                         ...
# 958   959                  3 Days to Kill       Action,Drama,Thriller
# 968   969                         Wrecker      Action,Horror,Thriller
# 969   970                 The Lone Ranger    Action,Adventure,Western
# 990   991  Underworld: Rise of the Lycans    Action,Adventure,Fantasy
# 993   994        Resident Evil: Afterlife     Action,Adventure,Horror
#
#                                            Description            Director  \
# ...

# %%
IMDB[IMDB['Genre'].str.contains('Horror')]
# Out:
#      Rank                             Title                    Genre  \
# 2       3                             Split          Horror,Thriller
# 22     23                    Hounds of Love       Crime,Drama,Horror
# 27     28                        Dead Awake          Horror,Thriller
# 34     35  Resident Evil: The Final Chapter     Action,Horror,Sci-Fi
# 42     43           Don't Fuck in the Woods                   Horror
# ..    ...                               ...                      ...
# 973   974                          Scream 4           Horror,Mystery
# 986   987               Final Destination 5          Horror,Thriller
# 988   989                           Martyrs                   Horror
# 993   994          Resident Evil: Afterlife  Action,Adventure,Horror
# 996   997                   Hostel: Part II                   Horror
#
#                                            Description            Director  \
# ...

# %%
a=IMDB[IMDB["Genre"].isin(["Action","Adventure","Sci-Fi","Horror"])]

# %%
a["Genre"].value_counts()
# Out:
# Genre
# Horror       11
# Action        2
# Sci-Fi        2
# Adventure     1
# Name: count, dtype: int64
